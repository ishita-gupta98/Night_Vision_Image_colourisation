# %% [markdown]
# #Computer vision Project - Inverted Colourisation
# ### By Han Chenfeng and Ishita Gupta

# %% [markdown]
# References : https://github.com/jantic/DeOldify

# %%
import torch

if not torch.cuda.is_available():
    print('GPU not available.')

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# Out:
# Cloning into 'DeOldify'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 1921 (delta 5), reused 15 (delta 3), pack-reused 1898
# Receiving objects: 100% (1921/1921), 69.28 MiB | 28.52 MiB/s, done.
# Resolving deltas: 100% (828/828), done.

# %%
cd DeOldify
# Out:
# /content/DeOldify/DeOldify/DeOldify/DeOldify

# %%
# !pip install -r requirements.txt

# %%
import fastai
from deoldify.visualize import *

torch.backends.cudnn.benchmark = True

# %%
# !mkdir 'models'
# !wget https://www.dropbox.com/s/zkehq1uwahhbc2o/ColorizeArtistic_gen.pth?dl=0 -O ./models/ColorizeArtistic_gen.pth
# Out:
# --2019-12-06 07:42:07--  https://www.dropbox.com/s/zkehq1uwahhbc2o/ColorizeArtistic_gen.pth?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/zkehq1uwahhbc2o/ColorizeArtistic_gen.pth [following]
# --2019-12-06 07:42:07--  https://www.dropbox.com/s/raw/zkehq1uwahhbc2o/ColorizeArtistic_gen.pth
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfd833fc36ec0d54ad427594f81.dl.dropboxusercontent.com/cd/0/inline/AtvKRgRbi_Ei44vc-6WnMeUGRGn21BcAnycFNnYkEKPCVo_OFFgBGvLoPH-NwM8tkABP4-YgrrE4Kxbs6rVxW0oqcQXbR435xfMZNrcBSDnvpw/file# [following]
# ...

# %%
colorizer = get_image_colorizer(artistic=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   def __repr__(self)->str:
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:457: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   def __getattr__(self, k):

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd '/content/drive/'
# Out:
# /content/drive

# %%
from PIL import Image
import PIL.ImageOps    

image = Image.open('/content/drive/My Drive/Colab Notebooks/images 3/set01/V003/lwir/I00653.jpg')
image.format ="PNG"
image.show()

inverted_image = PIL.ImageOps.invert(image)

inverted_image.save('/content/drive/My Drive/Colab Notebooks/images 3/result.png')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/My Drive/Colab Notebooks/images 3/set01/V003/lwir/I00653.jpg')
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
for i in range(7,10,1):
    colorizer.plot_transformed_image('/content/drive/My Drive/Colab Notebooks/images 3/result.png', render_factor=i, display_render_factor=True, figsize=(8,8))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-b8aec6df5bbd> in <module>()
#       1 for i in range(7,10,1):
# ----> 2     colorizer.plot_transformed_image('/content/drive/My Drive/Colab Notebooks/images 3/result.png', render_factor=i, display_render_factor=True, figsize=(8,8))
#
# /content/DeOldify/DeOldify/deoldify/visualize.py in plot_transformed_image(self, path, figsize, render_factor, display_render_factor, compare)
#      75             self._plot_solo(figsize, render_factor, display_render_factor, result)
#      76
# ---> 77         return self._save_result_image(path, result)
#      78
#      79     def _plot_comparison(
#
# /content/DeOldify/DeOldify/deoldify/visualize.py in _save_result_image(self, source_path, image)
#     119     def _save_result_image(self, source_path: Path, image: Image) -> Path:
# ...
